# %% [markdown]
# #Modes:
#
# train, val, predict
#
# #Tasks:
#
# detect, segment, classify
#
# #Data:
#
# Format can be differ for task type, Supports data.yaml, data_folder, data_name

# %% [markdown]
# # Installation

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 44.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## CMD

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # 1. Detection:

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/image.jpg"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/image.jpg: 448x640 2 persons, 1 bicycle, 1 motorcycle, 1 dog, 82.6ms
# Speed: 15.7ms preprocess, 82.6ms inference, 50.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 2. Segmentation:

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source="/content/image.jpg"
# Out:
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,404,320 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1 /content/image.jpg: 448x640 2 persons, 1 bicycle, 1 dog, 56.7ms
# Speed: 3.1ms preprocess, 56.7ms inference, 77.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## Python Script

# %%
from ultralytics import YOLO

# Load a segmentation model
model = YOLO("yolov8n-seg.pt")
model.predict(source="/content/image.jpg")
# Out:
# image 1/1 /content/image.jpg: 448x640 2 persons, 1 bicycle, 1 dog, 56.6ms
# Speed: 3.1ms preprocess, 56.6ms inference, 29.4ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %% [markdown]
# # 3. Classification:

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="/content/image.jpg"
# Out:
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n-cls summary (fused): 30 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# image 1/1 /content/image.jpg: 224x224 Welsh_springer_spaniel 0.29, English_springer 0.19, cocker_spaniel 0.13, Bernese_mountain_dog 0.04, Blenheim_spaniel 0.03, 2.7ms
# Speed: 38.5ms preprocess, 2.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
